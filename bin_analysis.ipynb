# %%
import pandas as pd
import QCircNet.utils as ut

PLOT_PATH = "results/plots/"

# %%
df  = pd.read_csv("results/final_bin_model_results_expID_0.csv", index_col=0)
df.sort_values(by="f1_score", inplace=True, ascending=False)
df.head(5)
# Out:
#     id  f1_score  precision    recall  accuracy  cross_entropy  seed  \
# 46  46  0.996805   0.996805  0.996805  0.996716       0.010587     6
# 50  50  0.996800   0.998397  0.995208  0.996716       0.012435     7
# 0    0  0.996022   0.992076  1.000000  0.995895       0.017164     1
# 8    8  0.996003   0.996800  0.995208  0.995895       0.016125     2
# 30  30  0.996003   0.996800  0.995208  0.995895       0.016933     4
#
#                         circuit  learning_rate  \
# 46  DoubleEntanglementVLCircuit           0.01
# 50         Senokosov2024Circuit           0.01
# 0              Ranga2024Circuit           0.01
# 8              Ranga2024Circuit           0.01
# 30  DoubleEntanglementVLCircuit           0.01
#
#                                          loss_history  avg_epoch_time_seconds  \
# 46  [0.16241673720804484, 0.02855318027554619, 0.0...               69.153696
# 50  [0.17037289913002351, 0.023847255617606845, 0....              116.717672
# 0   [0.1194998185291249, 0.02889960845028614, 0.02...              159.599353
# 8   [0.11087902408632401, 0.028543870192247835, 0....              164.906102
# 30  [0.13353034393788366, 0.02983052949084116, 0.0...               68.942889
#
#                                            model_path  epochs  n_qubits  \
# 46  results/models/bin/DoubleEntanglementVLCircuit...      10         4
# 50  results/models/bin/Senokosov2024Circuit_expID_...      10         4
# 0   results/models/bin/Ranga2024Circuit_expID_0_df...      10         4
# 8   results/models/bin/Ranga2024Circuit_expID_0_df...      10         4
# 30  results/models/bin/DoubleEntanglementVLCircuit...      10         4
#
#     features_per_qubit        scaler
# 46                   4  MinMaxScaler
# 50                   4  MinMaxScaler
# 0                    4  MinMaxScaler
# 8                    4  MinMaxScaler
# 30                   4  MinMaxScaler

# %%
ut.plot_training_history(df, run_id=46, save_path=PLOT_PATH)

# %%
# group by circuit, learning_rate
avg_results = df.copy()
avg_results = avg_results.groupby(["circuit", "learning_rate"]).mean(numeric_only=True)
avg_results.drop(columns=["id", "seed", "epochs", "n_qubits", "features_per_qubit"], inplace=True)

# %%
avg_results.sort_values(by="f1_score", ascending=False)
# Out:
#                                            f1_score  precision    recall  \
# circuit                     learning_rate
# Ranga2024Circuit            0.010          0.995317   0.996354  0.994295
# DoubleEntanglementVLCircuit 0.010          0.994846   0.998166  0.991556
# Senokosov2024Circuit        0.010          0.994040   0.998160  0.989959
# Anusha2024Circuit           0.010          0.994038   0.998620  0.989503
# Ranga2024Circuit            0.001          0.993695   0.998387  0.989046
# Anusha2024Circuit           0.001          0.993579   0.998387  0.988818
# Senokosov2024Circuit        0.001          0.993350   0.998157  0.988590
# DoubleEntanglementVLCircuit 0.001          0.993238   0.997699  0.988818
#
#                                            accuracy  cross_entropy  \
# circuit                     learning_rate
# Ranga2024Circuit            0.010          0.995191       0.014951
# DoubleEntanglementVLCircuit 0.010          0.994722       0.015345
# Senokosov2024Circuit        0.010          0.993901       0.015571
# Anusha2024Circuit           0.010          0.993901       0.019581
# Ranga2024Circuit            0.001          0.993549       0.024865
# Anusha2024Circuit           0.001          0.993432       0.033055
# Senokosov2024Circuit        0.001          0.993197       0.027056
# DoubleEntanglementVLCircuit 0.001          0.993080       0.031376
#
#                                            avg_epoch_time_seconds
# circuit                     learning_rate
# Ranga2024Circuit            0.010                      153.444440
# DoubleEntanglementVLCircuit 0.010                       72.733510
# Senokosov2024Circuit        0.010                      123.892049
# Anusha2024Circuit           0.010                       49.887938
# Ranga2024Circuit            0.001                      153.323604
# Anusha2024Circuit           0.001                       49.845276
# Senokosov2024Circuit        0.001                      123.832689
# DoubleEntanglementVLCircuit 0.001                       72.920293

# %%
df  = pd.read_csv("results/old_bin_experiment.csv", index_col=0)
df.sort_values(by="f1_score", inplace=True, ascending=False)
df.head(5)
# Out:
#     id  f1_score  precision    recall  accuracy  binary_cross_entropy  seed  \
# 13  13  0.931696   0.896603  0.969649  0.926929              0.541783     2
# 12  12  0.930375   0.892805  0.971246  0.925287              0.295634     2
# 14  14  0.927605   0.923930  0.931310  0.925287              0.670121     2
# 21  21  0.914605   0.913876  0.915335  0.912151              0.252111     3
# 22  22  0.912309   0.918963  0.905751  0.910509              0.276721     3
#
#                       circuit  learning_rate  \
# 13  DoubleEntanglementCircuit          0.010
# 12  DoubleEntanglementCircuit          0.100
# 14  DoubleEntanglementCircuit          0.001
# 21  DoubleEntanglementCircuit          0.100
# 22  DoubleEntanglementCircuit          0.010
#
#                                          loss_history  \
# 13  [0.683505382780966, 0.6719555354824192, 0.6599...
# 12  [0.6434025346840683, 0.563844397958172, 0.5047...
# 14  [0.6934171967992657, 0.687427958767665, 0.6861...
# 21  [0.43908821801213843, 0.2844262266237485, 0.25...
# 22  [0.6732281403321969, 0.583327370450685, 0.5145...
#
#                                      val_loss_history  \
# 13  [0.6800035834312439, 0.6689444780349731, 0.656...
# 12  [0.6108754873275757, 0.5370314121246338, 0.491...
# 14  [0.6887036561965942, 0.6869704127311707, 0.685...
# 21  [0.3435186743736267, 0.3059956431388855, 0.296...
# 22  [0.6277803778648376, 0.554211437702179, 0.4983...
#
#                                               val_f1s        scaler
# 13  [0.0374414976599064, 0.1844380403458213, 0.800...  MinMaxScaler
# 12  [0.3634020618556701, 0.9163408913213448, 0.913...  MinMaxScaler
# 14  [0.0031847133757961785, 0.2640990371389271, 0....  MinMaxScaler
# 21  [0.9038461538461539, 0.9055690072639225, 0.906...  MinMaxScaler
# 22  [0.878682842287695, 0.9120788824979458, 0.9053...  MinMaxScaler

# %%
ut.plot_training_history(df, run_id=13, save_path=PLOT_PATH, val=True)
