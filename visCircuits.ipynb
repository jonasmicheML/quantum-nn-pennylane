# %%
import QuantumCircuitNetwork as qcn
import CustomNetworks as cn

# %%
qnc = qcn.QuantumCircuitNetwork()
qnc.draw(figwidth=8)

# %%
cn.get_custom_circuits()
# Out:
# [CustomNetworks.Anusha2024Circuit,
#  CustomNetworks.DoubleEntanglementVLCircuit,
#  CustomNetworks.Ranga2024Circuit,
#  CustomNetworks.Senokosov2024Circuit]

# %%
figwidths = [10, 12, 40, 20] # custom circuit widths
# print all the custom circuits
for CircuitClass, figwidth in zip(cn.get_custom_circuits(), figwidths):
    circuit = CircuitClass()
    # print(circuit.__class__.__name__)
    fig = circuit.draw(figwidth=figwidth)
    display(fig)
